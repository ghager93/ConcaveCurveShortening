# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

from bin.morphology.transforms import edge_transform

# %%
# %matplotlib notebook

# %%
im = np.array(Image.open('lib/silhouettes/belize-silhouette.bmp').convert('1').resize((200, 200)))
edge = edge_transform(im)

# %%
plt.imshow(edge)
# Out:
# <img src="data:image/png;base64,..." width="640">
