# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image

from bin.curve_shortening_flow.main import _curvature0, _curvature_n
from bin.edge_loop import EdgeLoop
from bin.adj_image_array import invert

# %%
# %matplotlib notebook

# %%
# %matplotlib inline

# %%
im = np.pad(invert(np.array(Image.open('lib/silhouettes/afghanistan-silhouette.bmp').convert('L'))), 1)

# %%
edge_loop = EdgeLoop(im).edge_loop()

# %%
c0 = _curvature0(edge_loop)
c1 = _curvature_n(edge_loop, 1)
c2 = _curvature_n(edge_loop, 2)
c0.shape, c1.shape
# Out:
# ((10377,), (10377,))

# %%
plt.plot(c0)
plt.plot(c1)
plt.plot(c2)

# %%
ax = plt.figure().add_subplot(111)
ax.scatter([p[0] for p in edge_loop][::100], [p[1] for p in edge_loop][::100], c=c1[::100])
plt.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# []

# %%
len(edge_loop[::3])
# Out:
# 3459
